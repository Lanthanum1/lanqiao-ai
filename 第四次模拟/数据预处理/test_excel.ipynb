# %%
import pandas as pd 
excel_file = pd.read_excel("./2022_january.xlsx")
excel_file
# Out:
#     Unnamed: 0  Unnamed: 1           Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0          NaN         NaN                  NaN        NaN        NaN
# 1          NaN         NaN         2022年度1月份消费表        NaN        NaN
# 2          NaN         NaN                  NaN        NaN        NaN
# 3          NaN         NaN                 date       food    clothes
# 4          NaN         NaN  2022-01-01 00:00:00        804       2088
# 5          NaN         NaN  2022-01-02 00:00:00       1390       2781
# 6          NaN         NaN  2022-01-03 00:00:00       1291       2816
# 7          NaN         NaN  2022-01-04 00:00:00        629       1093
# 8          NaN         NaN  2022-01-05 00:00:00       1151       2476
# 9          NaN         NaN  2022-01-06 00:00:00       1586       2399
# 10         NaN         NaN  2022-01-07 00:00:00        380        140
# 11         NaN         NaN  2022-01-08 00:00:00        100       2023
# ...
